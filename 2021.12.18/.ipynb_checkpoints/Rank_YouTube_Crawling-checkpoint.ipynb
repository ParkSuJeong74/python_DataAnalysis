# %% [markdown]
# ## 유튜브 랭킹
#
# ### HTML 뭉치 찾기(10개)
# - channel_list

# %%
# import 라이브러리명
# 라이브러리 중 명령어 몇개만 준비! : from

import chromedriver_autoinstaller
from selenium import webdriver # selenium의 webdriver import 함
from bs4 import BeautifulSoup

# chromedriver 버전 업데이트
chromedriver_autoinstaller.install()

# 브라우저 열기
browser = webdriver.Chrome() # 컴퓨터용 브라우저

url="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=1"
browser.get(url)

# %%
# 100개 채널, 채널명, 카테고리, 구독자수, 조회수, 영상 개수
html=browser.page_source
soup=BeautifulSoup(html, "html.parser")

# %%
# 채널 리스트
channel_list = soup.select("table > tbody > tr.aos-init") # 100개 담김
len(channel_list)
# Out:
# 100

# %% [markdown]
# ### 1개의 채널에서 필요한 정보찾기

# %%
channel = channel_list[0] # 첫번째 채널
len(channel)
# Out:
# 15

# %%
# 채널명 찾기
title = channel.select("h1>a")[0].text
print(title.strip())
# Out:
# BLACKPINK

# %%
# 카테고리 찾기
category = channel.select("p.category")[0].text
print(category.strip())
# Out:
# [음악/댄스/가수]

# %%
# 구독자수 찾기
category = channel.select("td.subscriber_cnt")[0].text
print(category.strip())
# Out:
# 7060만

# %%
# 조회수 찾기
subscriber = channel.select("td.view_cnt")[0].text
print(subscriber.strip())
# Out:
# 216억3224만

# %%
# 영상 개수 찾기
video = channel.select("td.video_cnt")[0].text
print(video.strip())
# Out:
# 395개

# %% [markdown]
# ### 100개의 채널에서 찾기

# %%
for channel in channel_list:
    title = channel.select("h1>a")[0].text
    print(title.strip())
# Out:
# BLACKPINK
# HYBE LABELS
# BANGTANTV
# SMTOWN
# Boram Tube Vlog [보람튜브 브이로그]
# 1MILLION Dance Studio
# 1theK (원더케이)
# JYP Entertainment
# Mnet K-POP
# JFlaMusic
# KBS WORLD TV
# Jane ASMR 제인
# officialpsy
# BIGBANG
# TWICE
# Hongyu ASMR 홍유
# Nao FunFun
# Stone Music Entertainment
# DuDuPopTOY
# 핑크퐁 (인기 동요・동화)
# MBCkpop
# Toymong tv 토이몽TV
# Larva TUBA
# 서은이야기[SeoeunStory]
# Mnet TV
# EXO
# MBCentertainment
# [햄지]Hamzy
# iKON
# TOMORROW X TOGETHER OFFICIAL
# Stray Kids
# M2
# Serie A
# MariAndKids
# SEVENTEEN
# SonicToy소닉토이
# 이지금 [IU Official]
# 쏘영 Ssoyoung
# 문복희 Eat with Boki
# JTBC Entertainment
# Sungha Jung
# KBS Kpop
# Pixar
# ALL THE K-POP
# YG ENTERTAINMENT
# MAMAMOO
# ITZY
# 서은일상이야기
# 스브스케이팝 / SBS KPOP
# GOT7
# SBS Entertainment
# tvN drama
# Samsung
# PONY Syndrome
# [장난감티비]TOYTV
# SBS Drama
# 미니특공대TV
# 야미보이 Yummyboy
# 스위트티비 SweetTV
# 2NE1
# 백종원의 요리비책 Paik's Cuisine
# 콩순이 • 시크릿 쥬쥬 [Kongsuni • Secret Jouju]
# [Awesome Haeun]어썸하은
# tzuyang쯔양
# starshipTV
# ToyMart TV
# 베이비버스 -인기 동요・동화
# TOY GUMA
# BT21
# SBS NOW / SBS 공식 채널
# TREASURE (트레저)
# NCT
# Red Velvet
# With Kids Playground [위드키즈 놀이터]
# KBS Entertain
# 푸메Fume
# 떵개떵
# ASTRO 아스트로
# 영국남자 Korean Englishman
# 뽀로로(Pororo)
# MBCdrama
# 하루한끼 one meal a day
# 채널 NCT DAILY
# NCT 127
# 슈슈토이 Shushu ToysReview
# Cooking tree 쿠킹트리
# NCT DREAM
# SBS TV동물농장x애니멀봐
# EA SPORTS FIFA
# JTBC Drama
# Raon Lee
# 까니짱 [ G-NI ]
# 로미유 스토리[Romiyu Story]
# [Dorothy]도로시
# JaeYeol ASMR 재열
# CoCosToy 꼬꼬스토이
# 허팝Heopop
# 워크맨-Workman
# WINNER
# 크림히어로즈

# %%
for channel in channel_list:
    category = channel.select("p.category")[0].text
    print(category.strip())
# Out:
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [키즈/어린이]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [TV/방송]
# [음식/요리/레시피]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음식/요리/레시피]
# [키즈/어린이]
# [음악/댄스/가수]
# [키즈/어린이]
# [키즈/어린이]
# [TV/방송]
# [키즈/어린이]
# [키즈/어린이]
# [키즈/어린이]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [뉴스/정치/사회]
# [음식/요리/레시피]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [TV/방송]
# [해외]
# [키즈/어린이]
# [음악/댄스/가수]
# [키즈/어린이]
# [음악/댄스/가수]
# [음식/요리/레시피]
# [음식/요리/레시피]
# [뉴스/정치/사회]
# [음악/댄스/가수]
# [TV/방송]
# [미분류]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [키즈/어린이]
# [TV/방송]
# [음악/댄스/가수]
# [TV/방송]
# [TV/방송]
# [회사/오피셜]
# [패션/미용]
# [키즈/어린이]
# [TV/방송]
# [키즈/어린이]
# [음식/요리/레시피]
# [키즈/어린이]
# [음악/댄스/가수]
# [음식/요리/레시피]
# [키즈/어린이]
# [BJ/인물/연예인]
# [음식/요리/레시피]
# [음악/댄스/가수]
# [키즈/어린이]
# [키즈/어린이]
# [키즈/어린이]
# [음악/댄스/가수]
# [뉴스/정치/사회]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [음악/댄스/가수]
# [키즈/어린이]
# [TV/방송]
# [음식/요리/레시피]
# [음식/요리/레시피]
# [음악/댄스/가수]
# [BJ/인물/연예인]
# [키즈/어린이]
# [TV/방송]
# [음식/요리/레시피]
# [TV/방송]
# [음악/댄스/가수]
# [키즈/어린이]
# [음식/요리/레시피]
# [음악/댄스/가수]
# [애완/반려동물]
# [게임]
# [TV/방송]
# [음악/댄스/가수]
# [음식/요리/레시피]
# [키즈/어린이]
# [음식/요리/레시피]
# [취미/라이프]
# [키즈/어린이]
# [BJ/인물/연예인]
# [TV/방송]
# [음악/댄스/가수]
# [애완/반려동물]

# %%
for channel in channel_list:
    subscriber = channel.select("td.subscriber_cnt")[0].text
    print(subscriber.strip())
# Out:
# 7060만
# 6320만
# 6190만
# 2940만
# 2650만
# 2460만
# 2380만
# 2320만
# 1910만
# 1740만
# 1730만
# 1560만
# 1530만
# 1390만
# 1260만
# 1100만
# 1070만
# 1020만
# 1010만
# 1000만
# 962만
# 961만
# 953만
# 943만
# 870만
# 856만
# 851만
# 849만
# 843만
# 835만
# 815만
# 787만
# 771만
# 754만
# 730만
# 727만
# 718만
# 716만
# 705만
# 703만
# 679만
# 658만
# 652만
# 652만
# 652만
# 641만
# 637만
# 633만
# 620만
# 613만
# 595만
# 594만
# 593만
# 590만
# 580만
# 579만
# 573만
# 562만
# 561만
# 537만
# 523만
# 519만
# 517만
# 508만
# 501만
# 492만
# 489만
# 485만
# 480만
# 476만
# 472만
# 464만
# 463만
# 462만
# 460만
# 459만
# 458만
# 454만
# 450만
# 449만
# 448만
# 440만
# 432만
# 429만
# 429만
# 429만
# 427만
# 427만
# 426만
# 426만
# 424만
# 422만
# 419만
# 416만
# 398만
# 391만
# 384만
# 380만
# 379만
# 378만

# %%
for channel in channel_list:
    video = channel.select("td.video_cnt")[0].text
    print(video.strip())
# Out:
# 395개
# 731개
# 1,649개
# 3,786개
# 223개
# 3,431개
# 15,732개
# 1,432개
# 26,922개
# 281개
# 54,232개
# 1,311개
# 91개
# 773개
# 709개
# 425개
# 37개
# 8,374개
# 1,922개
# 2,406개
# 41,676개
# 1,933개
# 2,990개
# 1,052개
# 19,321개
# 238개
# 88,436개
# 371개
# 470개
# 915개
# 526개
# 15,073개
# 21,356개
# 809개
# 976개
# 163개
# 136개
# 517개
# 505개
# 66,949개
# 1,288개
# 30,851개
# 691개
# 21,133개
# 389개
# 629개
# 503개
# 622개
# 27,576개
# 579개
# 218,690개
# 37,884개
# 1,646개
# 196개
# 1,529개
# 341,738개
# 1,183개
# 902개
# 512개
# 321개
# 368개
# 1,286개
# 515개
# 295개
# 1,987개
# 651개
# 1,341개
# 306개
# 209개
# 20,506개
# 294개
# 250개
# 153개
# 411개
# 102,781개
# 504개
# 4,446개
# 472개
# 445개
# 3,707개
# 54,948개
# 172개
# 467개
# 291개
# 640개
# 1,182개
# 244개
# 3,211개
# 795개
# 23,532개
# 296개
# 542개
# 434개
# 907개
# 1,025개
# 656개
# 1,905개
# 157개
# 452개
# 1,016개

# %%
for channel in channel_list:
    title = channel.select("h1>a")[0].text.strip()
    category = channel.select("p.category")[0].text.strip()
    subscriber = channel.select("td.subscriber_cnt")[0].text.strip()
    view = channel.select('td.view_cnt')[0].text.strip()
    video = channel.select("td.video_cnt")[0].text.strip()
    print(title, category, subscriber, view, video)
# Out:
# BLACKPINK [음악/댄스/가수] 7060만 216억3224만 395개
# HYBE LABELS [음악/댄스/가수] 6320만 206억4055만 731개
# BANGTANTV [음악/댄스/가수] 6190만 142억4709만 1,649개
# SMTOWN [음악/댄스/가수] 2940만 231억5075만 3,786개
# Boram Tube Vlog [보람튜브 브이로그] [키즈/어린이] 2650만 110억5288만 223개
# 1MILLION Dance Studio [음악/댄스/가수] 2460만 69억5197만 3,431개
# 1theK (원더케이) [음악/댄스/가수] 2380만 214억1761만 15,732개
# JYP Entertainment [음악/댄스/가수] 2320만 151억1694만 1,432개
# Mnet K-POP [음악/댄스/가수] 1910만 140억8876만 26,922개
# JFlaMusic [음악/댄스/가수] 1740만 35억1106만 281개
# KBS WORLD TV [TV/방송] 1730만 129억1182만 54,232개
# Jane ASMR 제인 [음식/요리/레시피] 1560만 55억4665만 1,311개
# officialpsy [음악/댄스/가수] 1530만 88억6450만 91개
# BIGBANG [음악/댄스/가수] 1390만 68억4957만 773개
# TWICE [음악/댄스/가수] 1260만 27억4451만 709개
# Hongyu ASMR 홍유 [음식/요리/레시피] 1100만 31억9306만 425개
# Nao FunFun [키즈/어린이] 1070만 450만 37개
# Stone Music Entertainment [음악/댄스/가수] 1020만 83억0985만 8,374개
# DuDuPopTOY [키즈/어린이] 1010만 45억4032만 1,922개
# 핑크퐁 (인기 동요・동화) [키즈/어린이] 1000만 60억3473만 2,406개
# MBCkpop [TV/방송] 962만 76억5047만 41,676개
# Toymong tv 토이몽TV [키즈/어린이] 961만 39억6791만 1,933개
# Larva TUBA [키즈/어린이] 953만 41억8445만 2,990개
# 서은이야기[SeoeunStory] [키즈/어린이] 943만 40억6459만 1,052개
# Mnet TV [음악/댄스/가수] 870만 101억8310만 19,321개
# EXO [음악/댄스/가수] 856만 5억3771만 238개
# MBCentertainment [뉴스/정치/사회] 851만 149억5547만 88,436개
# [햄지]Hamzy [음식/요리/레시피] 849만 25억3834만 371개
# iKON [음악/댄스/가수] 843만 21억6771만 470개
# TOMORROW X TOGETHER OFFICIAL [음악/댄스/가수] 835만 5억9742만 915개
# Stray Kids [음악/댄스/가수] 815만 13억4259만 526개
# M2 [TV/방송] 787만 60억0714만 15,073개
# Serie A [해외] 771만 26억2007만 21,356개
# MariAndKids [키즈/어린이] 754만 23억2456만 809개
# SEVENTEEN [음악/댄스/가수] 730만 24억2609만 976개
# SonicToy소닉토이 [키즈/어린이] 727만 30억1399만 163개
# 이지금 [IU Official] [음악/댄스/가수] 718만 11억7186만 136개
# 쏘영 Ssoyoung [음식/요리/레시피] 716만 7억0713만 517개
# 문복희 Eat with Boki [음식/요리/레시피] 705만 16억6509만 505개
# JTBC Entertainment [뉴스/정치/사회] 703만 101억6399만 66,949개
# Sungha Jung [음악/댄스/가수] 679만 18억9180만 1,288개
# KBS Kpop [TV/방송] 658만 51억4113만 30,851개
# Pixar [미분류] 652만 32억1584만 691개
# ALL THE K-POP [음악/댄스/가수] 652만 40억1126만 21,133개
# YG ENTERTAINMENT [음악/댄스/가수] 652만 16억6112만 389개
# MAMAMOO [음악/댄스/가수] 641만 18억0674만 629개
# ITZY [음악/댄스/가수] 637만 12억0656만 503개
# 서은일상이야기 [키즈/어린이] 633만 23억6633만 622개
# 스브스케이팝 / SBS KPOP [TV/방송] 620만 42억6271만 27,576개
# GOT7 [음악/댄스/가수] 613만 7억7982만 579개
# SBS Entertainment [TV/방송] 595만 70억8350만 218,690개
# tvN drama [TV/방송] 594만 60억6116만 37,884개
# Samsung [회사/오피셜] 593만 12억8820만 1,646개
# PONY Syndrome [패션/미용] 590만 3억4438만 196개
# [장난감티비]TOYTV [키즈/어린이] 580만 28억3721만 1,529개
# SBS Drama [TV/방송] 579만 61억1900만 341,738개
# 미니특공대TV [키즈/어린이] 573만 32억2446만 1,183개
# 야미보이 Yummyboy [음식/요리/레시피] 562만 20억5784만 902개
# 스위트티비 SweetTV [키즈/어린이] 561만 27억1449만 512개
# 2NE1 [음악/댄스/가수] 537만 19억9667만 321개
# 백종원의 요리비책 Paik's Cuisine [음식/요리/레시피] 523만 5억8077만 368개
# 콩순이 • 시크릿 쥬쥬 [Kongsuni • Secret Jouju] [키즈/어린이] 519만 46억2329만 1,286개
# [Awesome Haeun]어썸하은 [BJ/인물/연예인] 517만 8억1979만 515개
# tzuyang쯔양 [음식/요리/레시피] 508만 7억9044만 295개
# starshipTV [음악/댄스/가수] 501만 29억0918만 1,987개
# ToyMart TV [키즈/어린이] 492만 21억4921만 651개
# 베이비버스 -인기 동요・동화 [키즈/어린이] 489만 33억0998만 1,341개
# TOY GUMA [키즈/어린이] 485만 15억9955만 306개
# BT21 [음악/댄스/가수] 480만 3억9426만 209개
# SBS NOW / SBS 공식 채널 [뉴스/정치/사회] 476만 47억6579만 20,506개
# TREASURE (트레저) [음악/댄스/가수] 472만 9억4287만 294개
# NCT [음악/댄스/가수] 464만 3억3636만 250개
# Red Velvet [음악/댄스/가수] 463만 7억2149만 153개
# With Kids Playground [위드키즈 놀이터] [키즈/어린이] 462만 17억3122만 411개
# KBS Entertain [TV/방송] 460만 74억3341만 102,781개
# 푸메Fume [음식/요리/레시피] 459만 9억4452만 504개
# 떵개떵 [음식/요리/레시피] 458만 26억1310만 4,446개
# ASTRO 아스트로 [음악/댄스/가수] 454만 4억5034만 472개
# 영국남자 Korean Englishman [BJ/인물/연예인] 450만 14억6379만 445개
# 뽀로로(Pororo) [키즈/어린이] 449만 60억8666만 3,707개
# MBCdrama [TV/방송] 448만 50억6565만 54,948개
# 하루한끼 one meal a day [음식/요리/레시피] 440만 4억2852만 172개
# 채널 NCT DAILY [TV/방송] 432만 7억6605만 467개
# NCT 127 [음악/댄스/가수] 429만 4억8956만 291개
# 슈슈토이 Shushu ToysReview [키즈/어린이] 429만 16억0785만 640개
# Cooking tree 쿠킹트리 [음식/요리/레시피] 429만 4억0087만 1,182개
# NCT DREAM [음악/댄스/가수] 427만 4억8460만 244개
# SBS TV동물농장x애니멀봐 [애완/반려동물] 427만 39억0522만 3,211개
# EA SPORTS FIFA [게임] 426만 8억0363만 795개
# JTBC Drama [TV/방송] 426만 43억6880만 23,532개
# Raon Lee [음악/댄스/가수] 424만 9억6120만 296개
# 까니짱 [ G-NI ] [음식/요리/레시피] 422만 11억1612만 542개
# 로미유 스토리[Romiyu Story] [키즈/어린이] 419만 11억0059만 434개
# [Dorothy]도로시 [음식/요리/레시피] 416만 9억9925만 907개
# JaeYeol ASMR 재열 [취미/라이프] 398만 11억0189만 1,025개
# CoCosToy 꼬꼬스토이 [키즈/어린이] 391만 22억1064만 656개
# 허팝Heopop [BJ/인물/연예인] 384만 32억7545만 1,905개
# 워크맨-Workman [TV/방송] 380만 7억5282만 157개
# WINNER [음악/댄스/가수] 379만 12억1600만 452개
# 크림히어로즈 [애완/반려동물] 378만 14억1795만 1,016개

# %% [markdown]
# ### 다음 페이지 크롤링

# %%
page=2
url=f"https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={page}"
browser.get(url)

# %%
page=2
url=f"https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={page}"
browser.get(url) # 요청

html=browser.page_source # 이미 데이터가 들어가 있다고 생각하고 사진 찍음
soup=BeautifulSoup(html, "html.parser")

channel_list = soup.select("table > tbody > tr.aos-init") # 100개 담김

for channel in channel_list:
    title = channel.select("h1>a")[0].text.strip()
    category = channel.select("p.category")[0].text.strip()
    subscriber = channel.select("td.subscriber_cnt")[0].text.strip()
    view = channel.select('td.view_cnt')[0].text.strip()
    video = channel.select("td.video_cnt")[0].text.strip()
    print(title, category, subscriber, view, video)
# Out:
# Lime Tube[라임튜브] [키즈/어린이] 374만 26억5342만 1,819개
# waveya 2011 [BJ/인물/연예인] 373만 13억5771만 712개
# 백현 Baekhyun [음악/댄스/가수] 369만 4635만 16개
# ARTBEAT [BJ/인물/연예인] 365만 9억5745만 1,230개
# 채널 십오야 [TV/방송] 362만 7억5615만 513개
# Milana FamilyShow[EN] [키즈/어린이] 362만 9억8443만 187개
# TV-People [TV/방송] 361만 40억8086만 18,344개
# KBS Drama [TV/방송] 357만 44억6873만 116,983개
# Billboard [회사/오피셜] 348만 11억6909만 7,099개
# 제이제이 튜브 [JJ Tube] [키즈/어린이] 348만 21억8568만 500개
# 딩고 뮤직 / dingo music [TV/방송] 348만 12억8711만 1,622개
# drawholic [취미/라이프] 343만 3억8299만 343개
# ROSÉ Official [음악/댄스/가수] 338만 1318만 3개
# 솔라시도 solarsido [TV/방송] 336만 2억1449만 273개
# tvN [TV/방송] 334만 48억7404만 61,137개
# 리월드RIWORLD [키즈/어린이] 333만 12억8467만 198개
# 미니팡TV [키즈/어린이] 331만 22억8888만 637개
# KARD [음악/댄스/가수] 331만 6억1682만 315개
# (G)I-DLE (여자)아이들 (Official YouTube Channel) [음악/댄스/가수] 329만 10억2898만 203개
# STUDIO CHOOM [스튜디오 춤] [음악/댄스/가수] 328만 13억2081만 812개
# EBS 키즈 [키즈/어린이] 328만 41억5965만 19,370개
# MayTree [미분류] 327만 5억1685만 153개
# imlisarhee [음악/댄스/가수] 324만 4억5892만 583개
# 키즈팡TV [키즈/어린이] 323만 20억1764만 1,969개
# 럭키강이 LuckyKang i [키즈/어린이] 317만 13억7994만 1,283개
# tvN D ENT [TV/방송] 316만 58억8403만 16,494개
# MariAndToys [키즈/어린이] 315만 5억7002만 209개
# 장삐쭈 [영화/만화/애니] 308만 14억0875만 391개
# 카 로봇 Car Robot [키즈/어린이] 307만 18억0383만 3,534개
# 피지컬갤러리 [스포츠/운동] 306만 5억2189만 630개
# 5 분 Tricks [음식/요리/레시피] 305만 10억8768만 3,256개
# 사나고 Sanago [취미/라이프] 303만 4억0873만 148개
# 유디티TV [음식/요리/레시피] 303만 6억1795만 1,031개
# FRAN [음식/요리/레시피] 300만 10억7218만 1,800개
# Thankyou BUBU [취미/라이프] 298만 4억8897만 134개
# JTBC Voyage [TV/방송] 293만 34억6242만 7,826개
# 옛드 : 옛날 드라마 [드라맛집] [TV/방송] 293만 52억8284만 46,266개
# odg [취미/라이프] 292만 4억9497만 127개
# 새송 Saesong [음악/댄스/가수] 292만 2억9658만 252개
# HyunA [음악/댄스/가수] 287만 3억9927만 71개
# 양수빈 [음식/요리/레시피] 285만 5억0615만 245개
# 헤이지니 Hey Jini [키즈/어린이] 281만 17억6880만 1,264개
# JAY PARK [음악/댄스/가수] 278만 7억1257만 137개
# 한세 HANSE [음식/요리/레시피] 274만 3억8624만 573개
# 팬케이Pan K The Pancake Artist [취미/라이프] 274만 8억3416만 551개
# Jessi [음악/댄스/가수] 272만 4억2274만 56개
# 런닝맨 - 스브스 공식 채널 [TV/방송] 271만 36억2179만 53,782개
# YTN news [뉴스/정치/사회] 271만 61억2134만 574,154개
# TVCHOSUN - TV조선 [뉴스/정치/사회] 266만 43억8136만 67,440개
# 나도Nado [음식/요리/레시피] 265만 7억0533만 716개
# AKMU [음악/댄스/가수] 264만 7억1111만 148개
# 푸드킹덤 Food Kingdom [음식/요리/레시피] 260만 9억7152만 856개
# 지현꿍 [음식/요리/레시피] 260만 2억2677만 99개
# ATEEZ [TV/방송] 255만 2억8362만 397개
# ASMR PPOMO [취미/라이프] 254만 6억8701만 424개
# PLAYLIST ORIGINALS 플레이리스트 오리지널 [TV/방송] 254만 9억8740만 700개
# Boys Playtime [키즈/어린이] 251만 12억0031만 467개
# ZOEY ASMR 조이 [음식/요리/레시피] 250만 5억8222만 661개
# GIRLS' GENERATION [음악/댄스/가수] 249만 1억7572만 79개
# 애정 Aejeong [음식/요리/레시피] 246만 4억0473만 433개
# ToyFamily [키즈/어린이] 245만 42만 38개
# 보라미TV BoramiTV [키즈/어린이] 245만 8억4474만 595개
# EBSDocumentary (EBS 다큐) [TV/방송] 242만 21억9071만 29,129개
# THEBLACKLABEL [음악/댄스/가수] 240만 5억3607만 121개
# 꼬마버스 타요 [키즈/어린이] 239만 18억3491만 2,366개
# 김종국 GYM JONG KOOK [스포츠/운동] 236만 9042만 27개
# 도티 TV [게임] 236만 26억8375만 3,278개
# JOLLY [BJ/인물/연예인] 233만 5억3417만 361개
# International Couple[사샤와 제이] [BJ/인물/연예인] 232만 2억6636만 161개
# SBS Catch [뉴스/정치/사회] 231만 22억4284만 3,636개
# United CUBE (CUBE Entertainment Official YouTube Channel) [음악/댄스/가수] 231만 7억2719만 1,574개
# 와썹맨-Wassup Man [BJ/인물/연예인] 230만 3억1463만 179개
# GH'S [미분류] 228만 9억6093만 118개
# 창현노래방 [음악/댄스/가수] 227만 2억8344만 835개
# 흔한남매 [BJ/인물/연예인] 227만 22억6257만 832개
# MONSTA X [음악/댄스/가수] 225만 2억8877만 141개
# 채널 NCT MUSIC [음악/댄스/가수] 225만 1억7251만 29개
# 여자친구 GFRIEND OFFICIAL [음악/댄스/가수] 225만 4억6656만 515개
# VIVA DANCE STUDIO [BJ/인물/연예인] 225만 3억9655만 2,304개
# RISABAE [패션/미용] 225만 2억7055만 378개
# SHINee [음악/댄스/가수] 224만 2억1629만 156개
# The Wiggles [해외] 223만 26억6306만 679개
# The K-POP [음악/댄스/가수] 223만 6억5201만 8,100개
# 엔조이커플enjoycouple [BJ/인물/연예인] 223만 8억2428만 562개
# 총몇명 [영화/만화/애니] 223만 8억1342만 330개
# MariAndFriends [키즈/어린이] 221만 15억3360만 1,815개
# 스브스 예능맛집 [TV/방송] 220만 17억0665만 3,614개
# 또봇 V · 메탈리온 [Tobot V · Metalions] [키즈/어린이] 220만 27억5009만 1,919개
# 진용진 [BJ/인물/연예인] 219만 6억6397만 438개
# SUPER JUNIOR [음악/댄스/가수] 219만 1억1387만 221개
# official IZ*ONE [음악/댄스/가수] 219만 5억8263만 270개
# 해그린달 haegreendal [BJ/인물/연예인] 219만 9101만 60개
# 채널 NCT DANCE [음악/댄스/가수] 218만 1억9472만 42개
# 꿀키honeykki [음식/요리/레시피] 216만 2억6940만 432개
# 흥삼이네 Heungsam's Family [음식/요리/레시피] 216만 10억7997만 1,422개
# 토닥토닥 꼬모 - 애니메이션, 동요, 놀이 [키즈/어린이] 214만 25억3812만 877개
# OfficialGDRAGON [음악/댄스/가수] 212만 6724만 0개
# 4Minute 포미닛(Official YouTube Channel) [음악/댄스/가수] 211만 12억7011만 82개
# 감스트GAMST [게임] 211만 14억5725만 4,473개
# [wonderkids TV] 원더키즈 TV [키즈/어린이] 210만 9억2943만 940개
